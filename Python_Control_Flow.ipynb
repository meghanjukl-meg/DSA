# %% [markdown]
# <a href="https://colab.research.google.com/github/meghanjukl-meg/DSA/blob/main/Python_Control_Flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Basics

# %% [markdown]
# ##Print statements

# %%
print("hello world")
# Out:
# hello world

# %%
print("new line")
# Out:
# new line

# %%
print(233)
# Out:
# 233

# %%
var = 65
name = "Megha"
print (var)
print(f"MY name is {name}")
# Out:
# 65
# MY name is Megha

# %%
Item_name = "Computer"
Item_qty =10
Item_value = 1000.23
print(Item_name)
print(Item_value)
print(Item_qty)
# Out:
# Computer
# 1000.23
# 10

# %% [markdown]
# ## Data types and functions

# %% [markdown]
# ### Number

# %%
print(type(Item_value))
# Out:
# <class 'float'>

# %%
type(-2)
# Out:
# int

# %% [markdown]
# #### Division

# %%
time= 96
hours = time // 60
minute = time % 60
print(f"{hours} hours and {minute} minutes")
# Out:
# 1 hours and 36 minutes

# %%
type(3+2j)
# Out:
# complex

# %% [markdown]
# ### String

# %%
print(type(Item_name))
# Out:
# <class 'str'>

# %% [markdown]
# #### String multiplication

# %%
print('1.3'*3)
# Out:
# 1.31.31.3

# %% [markdown]
# #### String slicing

# %%
num='3.14'

print((num[2:]))
print( (num[:2][::-1]))
# Out:
# 14
# .3

# %%
m="Good evening"
print("aswer")
print(m[-7:])
print(m[:2])
print(m[-7:2])
print(m[:4][::-1])
# Out:
# aswer
# evening
# Go
#
# dooG

# %% [markdown]
# ### Tuple

# %%
tuple= (1,2,3,4)
len(tuple)
# Out:
# 4

# %% [markdown]
# ### Dict

# %%
biodata={
    "Name" : "Megha",
    "Age" : 28
}
print(biodata["Age"])
print(type(Item_qty))
# Out:
# 28
# <class 'int'>

# %% [markdown]
# ### Control Flow

# %% [markdown]
# 1. IF
#     - simple if

# %%
x=9
y=6
if x > y:
  print(" X is greater than Y")
print("done")
# Out:
#  X is greater than Y
# done

# %% [markdown]
#   2. IF..ELSE..
#
#
#       - if (condition) :
#
#             statement
#         else:
#
#             statement

# %%
a=20
b=30
if None:
  print ("Inside")
else :
  print("else")
# Out:
# else

# %% [markdown]
# a=2
# b=1
# if 1/2/any character:
#      print("true)
# it will print true
# if None/0 /true
#          it will false

# %% [markdown]
# 3. IF.. ELIF.. ELSE..
#
#          if (condition):
#                    statements
#          elif (condition):
#                 statements
#          else:
#               statement

# %% [markdown]
# #### Panlindrome

# %%
string= "malayalam"
reverse = string[::-1]
if string == reverse:
    print("Panlindrome")
else:
    print("String is not panlindrome")
# Out:
# Panlindrome

# %% [markdown]
# #### check if name length >10

# %%
name = "       Data"
if len(name) > 10:
    print("Your name is long")
else:
    print("Your name is short")
# Out:
# Your name is long

# %% [markdown]
# #### checking week

# %%
day = 2
if day%7 ==0 :
    print("Sunday")
elif day%7 == 1 :
    print("Monday")
elif day%7 ==2 :
    print("Tuesday")
elif day%7 == 3:
    print("Wednesday")
elif day%7 == 4 :
    print("Thursday")
elif day%7 ==5 :
    print("Friday")
else:
    print("Saturday")
# Out:
# Tuesday

# %% [markdown]
# #### Convert to railway timing

# %%
hour= 13
minute = 10
if hour >12 :
    hour = hour - 12
    print(f"{hour}:{minute} PM")
elif hour == 12:
    print(f"{hour}:{minute} PM")
else:
    print(f"{hour}:{minute} AM")
# Out:
# 1:10 PM
